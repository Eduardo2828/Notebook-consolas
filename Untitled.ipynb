# %%
import pandas as pd

# Cargar el CSV
df = pd.read_csv("consoles.csv")

# Eliminar filas con al menos un valor nulo
df_limpio = df.dropna()

# (Opcional) Guardar el nuevo CSV
df_limpio.to_csv("consoles2.csv", index=False)

# Mostrar las primeras filas para verificar
df_limpio.head()
# Out:
#                     Name Platform  Year_of_Release     Genre Publisher  \
# 0             Wii Sports      Wii           2006.0    Sports  Nintendo
# 2         Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 3      Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 6  New Super Mario Bros.       DS           2006.0  Platform  Nintendo
# 7               Wii Play      Wii           2006.0      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 6     11.28      9.14      6.50         2.88         29.80          89.0
# 7     13.96      9.18      2.93         2.84         28.92          58.0
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 6          65.0        8.5       431.0  Nintendo      E
# 7          41.0        6.6       129.0  Nintendo      E

# %%
df = df.rename(columns={"Name": "Nombre"})

# %%
print(df.head())
# Out:
#                      Nombre Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
df_limpio.head()
# Out:
#                     Name Platform  Year_of_Release     Genre Publisher  \
# 0             Wii Sports      Wii           2006.0    Sports  Nintendo
# 2         Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 3      Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 6  New Super Mario Bros.       DS           2006.0  Platform  Nintendo
# 7               Wii Play      Wii           2006.0      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 6     11.28      9.14      6.50         2.88         29.80          89.0
# 7     13.96      9.18      2.93         2.84         28.92          58.0
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 6          65.0        8.5       431.0  Nintendo      E
# 7          41.0        6.6       129.0  Nintendo      E

# %%
df = df.rename(columns={"Platform": "Plataforma", "Year_of_Release": "Año_de_Lanzamiento", "Genre": "Género", "Publisher": "Editor", "NA_sales": "Ventas_NA", "EU_Sales": "Ventas_EU", "JP_Sales": "Ventas_JP", "Other_Sales": "Otras_Ventas", "Global_Sales": "Ventas_Globales", "Critic_Score": "Puntuación_de_la_crítica", "Critic_Count": "Número_de_críticas", "User_Score": "Puntuación_de_los_usuarios", "User_Count": "Número_de_usuarios", "Developer": "Desarrolladora", "Rating": "ESRB"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = df.rename(columns={"Platform": "Plataforma", "Year_of_Release": "Año_de_Lanzamiento", "Genre": "Género", "Publisher": "Editor", "NA_sales": "Ventas_NA", "EU_Sales": "Ventas_EU", "JP_Sales": "Ventas_JP", "Other_Sales": "Otras_Ventas", "Global_Sales": "Ventas_Globales", "Critic_Score": "Puntuación_de_la_crítica", "Critic_Count": "Número_de_críticas", "User_Score": "Puntuación_de_los_usuarios", "User_Count": "Número_de_usuarios", "Developer": "Desarrolladora", "Rating": "ESRB"})
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
import pandas as pd

# Cargar el CSV
df = pd.read_csv("consoles.csv")

# Eliminar filas con al menos un valor nulo
df_limpio = df.dropna()

# (Opcional) Guardar el nuevo CSV
df_limpio.to_csv("consoles2.csv", index=False)

# Mostrar las primeras filas para verificar
df_limpio.head()

df = df.rename(columns={
    "Platform": "Plataforma",
    "Year_of_Release": "Año_de_Lanzamiento",
    "Genre": "Género",
    "Publisher": "Editor",
    "NA_Sales": "Ventas_NA",
    "EU_Sales": "Ventas_EU",
    "JP_Sales": "Ventas_JP",
    "Other_Sales": "Otras_Ventas",
    "Global_Sales": "Ventas_Globales",
    "Critic_Score": "Puntuación_de_la_crítica",
    "Critic_Count": "Número_de_críticas",
    "User_Score": "Puntuación_de_los_usuarios",
    "User_Count": "Número_de_usuarios",
    "Developer": "Desarrolladora",
    "Rating": "ESRB"
})

# %%
print(df.head())
# Out:
#                        Name Plataforma  Año_de_Lanzamiento        Género  \
# 0                Wii Sports        Wii              2006.0        Sports
# 1         Super Mario Bros.        NES              1985.0      Platform
# 2            Mario Kart Wii        Wii              2008.0        Racing
# 3         Wii Sports Resort        Wii              2009.0        Sports
# 4  Pokemon Red/Pokemon Blue         GB              1996.0  Role-Playing
#
#      Editor  Ventas_NA  Ventas_EU  Ventas_JP  Otras_Ventas  Ventas_Globales  \
# 0  Nintendo      41.36      28.96       3.77          8.45            82.53
# 1  Nintendo      29.08       3.58       6.81          0.77            40.24
# 2  Nintendo      15.68      12.76       3.79          3.29            35.52
# 3  Nintendo      15.61      10.93       3.28          2.95            32.77
# 4  Nintendo      11.27       8.89      10.22          1.00            31.37
#
#    Puntuación_de_la_crítica  Número_de_críticas Puntuación_de_los_usuarios  \
# 0                      76.0                51.0                          8
# 1                       NaN                 NaN                        NaN
# 2                      82.0                73.0                        8.3
# 3                      80.0                73.0                          8
# 4                       NaN                 NaN                        NaN
#
#    Número_de_usuarios Desarrolladora ESRB
# 0               322.0       Nintendo    E
# 1                 NaN            NaN  NaN
# 2               709.0       Nintendo    E
# 3               192.0       Nintendo    E
# 4                 NaN            NaN  NaN

# %%
df = df.rename(columns={"Name": "Nombre"})

# %%
print(df.head())
# Out:
#                      Nombre Plataforma  Año_de_Lanzamiento        Género  \
# 0                Wii Sports        Wii              2006.0        Sports
# 1         Super Mario Bros.        NES              1985.0      Platform
# 2            Mario Kart Wii        Wii              2008.0        Racing
# 3         Wii Sports Resort        Wii              2009.0        Sports
# 4  Pokemon Red/Pokemon Blue         GB              1996.0  Role-Playing
#
#      Editor  Ventas_NA  Ventas_EU  Ventas_JP  Otras_Ventas  Ventas_Globales  \
# 0  Nintendo      41.36      28.96       3.77          8.45            82.53
# 1  Nintendo      29.08       3.58       6.81          0.77            40.24
# 2  Nintendo      15.68      12.76       3.79          3.29            35.52
# 3  Nintendo      15.61      10.93       3.28          2.95            32.77
# 4  Nintendo      11.27       8.89      10.22          1.00            31.37
#
#    Puntuación_de_la_crítica  Número_de_críticas Puntuación_de_los_usuarios  \
# 0                      76.0                51.0                          8
# 1                       NaN                 NaN                        NaN
# 2                      82.0                73.0                        8.3
# 3                      80.0                73.0                          8
# 4                       NaN                 NaN                        NaN
#
#    Número_de_usuarios Desarrolladora ESRB
# 0               322.0       Nintendo    E
# 1                 NaN            NaN  NaN
# 2               709.0       Nintendo    E
# 3               192.0       Nintendo    E
# 4                 NaN            NaN  NaN

# %%
df_limpio.head()
# Out:
#                     Name Platform  Year_of_Release     Genre Publisher  \
# 0             Wii Sports      Wii           2006.0    Sports  Nintendo
# 2         Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 3      Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 6  New Super Mario Bros.       DS           2006.0  Platform  Nintendo
# 7               Wii Play      Wii           2006.0      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 6     11.28      9.14      6.50         2.88         29.80          89.0
# 7     13.96      9.18      2.93         2.84         28.92          58.0
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 6          65.0        8.5       431.0  Nintendo      E
# 7          41.0        6.6       129.0  Nintendo      E

# %%
import pandas as pd

# Cargar el CSV
df = pd.read_csv("consoles2.csv")

# Eliminar filas con al menos un valor nulo
df_limpio = df.dropna()

# (Opcional) Guardar el nuevo CSV
df_limpio.to_csv("consoles2.csv", index=False)

# Mostrar las primeras filas para verificar
df_limpio.head()

df = df.rename(columns={
    "Platform": "Plataforma",
    "Year_of_Release": "Año_de_Lanzamiento",
    "Genre": "Género",
    "Publisher": "Editor",
    "NA_Sales": "Ventas_NA",
    "EU_Sales": "Ventas_EU",
    "JP_Sales": "Ventas_JP",
    "Other_Sales": "Otras_Ventas",
    "Global_Sales": "Ventas_Globales",
    "Critic_Score": "Puntuación_de_la_crítica",
    "Critic_Count": "Número_de_críticas",
    "User_Score": "Puntuación_de_los_usuarios",
    "User_Count": "Número_de_usuarios",
    "Developer": "Desarrolladora",
    "Rating": "ESRB"
})

# %%
df_limpio.head()
# Out:
#                     Name Platform  Year_of_Release     Genre Publisher  \
# 0             Wii Sports      Wii           2006.0    Sports  Nintendo
# 1         Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 2      Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 3  New Super Mario Bros.       DS           2006.0  Platform  Nintendo
# 4               Wii Play      Wii           2006.0      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     15.68     12.76      3.79         3.29         35.52          82.0
# 2     15.61     10.93      3.28         2.95         32.77          80.0
# 3     11.28      9.14      6.50         2.88         29.80          89.0
# 4     13.96      9.18      2.93         2.84         28.92          58.0
#
#    Critic_Count  User_Score  User_Count Developer Rating
# 0          51.0         8.0       322.0  Nintendo      E
# 1          73.0         8.3       709.0  Nintendo      E
# 2          73.0         8.0       192.0  Nintendo      E
# 3          65.0         8.5       431.0  Nintendo      E
# 4          41.0         6.6       129.0  Nintendo      E

# %%
print(df.head())
# Out:
#                     Name Plataforma  Año_de_Lanzamiento    Género    Editor  \
# 0             Wii Sports        Wii              2006.0    Sports  Nintendo
# 1         Mario Kart Wii        Wii              2008.0    Racing  Nintendo
# 2      Wii Sports Resort        Wii              2009.0    Sports  Nintendo
# 3  New Super Mario Bros.         DS              2006.0  Platform  Nintendo
# 4               Wii Play        Wii              2006.0      Misc  Nintendo
#
#    Ventas_NA  Ventas_EU  Ventas_JP  Otras_Ventas  Ventas_Globales  \
# 0      41.36      28.96       3.77          8.45            82.53
# 1      15.68      12.76       3.79          3.29            35.52
# 2      15.61      10.93       3.28          2.95            32.77
# 3      11.28       9.14       6.50          2.88            29.80
# 4      13.96       9.18       2.93          2.84            28.92
#
#    Puntuación_de_la_crítica  Número_de_críticas  Puntuación_de_los_usuarios  \
# 0                      76.0                51.0                         8.0
# 1                      82.0                73.0                         8.3
# 2                      80.0                73.0                         8.0
# 3                      89.0                65.0                         8.5
# 4                      58.0                41.0                         6.6
#
#    Número_de_usuarios Desarrolladora ESRB
# 0               322.0       Nintendo    E
# 1               709.0       Nintendo    E
# 2               192.0       Nintendo    E
# 3               431.0       Nintendo    E
# 4               129.0       Nintendo    E

# %%
import pandas as pd

# Cargar el CSV
df = pd.read_csv("consoles2.csv")

# Eliminar filas con al menos un valor nulo
df_limpio = df.dropna()

# (Opcional) Guardar el nuevo CSV
df_limpio.to_csv("consoles2.csv", index=False)

# Mostrar las primeras filas para verificar
df_limpio.head()

df = df.rename(columns={
    "Platform": "Plataforma",
    "Year_of_Release": "Año_de_Lanzamiento",
    "Genre": "Género",
    "Publisher": "Editor",
    "NA_Sales": "Ventas_NA",
    "EU_Sales": "Ventas_EU",
    "JP_Sales": "Ventas_JP",
    "Other_Sales": "Otras_Ventas",
    "Global_Sales": "Ventas_Globales",
    "Critic_Score": "Puntuación_de_la_crítica",
    "Critic_Count": "Número_de_críticas",
    "User_Score": "Puntuación_de_los_usuarios",
    "User_Count": "Número_de_usuarios",
    "Developer": "Desarrolladora",
    "Rating": "ESRB"
})

# %%
import pandas as pd

# 1. Cargar el CSV
df = pd.read_csv("consoles2.csv")

# 2. Ver las cabeceras originales
print(df.columns)

# 3. Renombrar las columnas al español
df = df.rename(columns={
    "Platform": "Plataforma",
    "Year_of_Release": "Año_de_Lanzamiento",
    "Genre": "Género",
    "Publisher": "Editor",
    "NA_Sales": "Ventas_NA",
    "EU_Sales": "Ventas_EU",
    "JP_Sales": "Ventas_JP",
    "Other_Sales": "Otras_Ventas",
    "Global_Sales": "Ventas_Globales",
    "Critic_Score": "Puntuación_Crítica",
    "Critic_Count": "Número_Críticas",
    "User_Score": "Puntuación_Usuarios",
    "User_Count": "Número_Usuarios",
    "Developer": "Desarrolladora",
    "Rating": "Clasificación_ESRB"
})

# 4. Confirmar los cambios
print(df.columns)

# 5. (Opcional) Guardar el CSV con las nuevas cabeceras
df.to_csv("consoles2_es.csv", index=False)
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')
# Index(['Name', 'Plataforma', 'Año_de_Lanzamiento', 'Género', 'Editor',
#        'Ventas_NA', 'Ventas_EU', 'Ventas_JP', 'Otras_Ventas',
#        'Ventas_Globales', 'Puntuación_Crítica', 'Número_Críticas',
#        'Puntuación_Usuarios', 'Número_Usuarios', 'Desarrolladora',
#        'Clasificación_ESRB'],
#       dtype='object')

# %%
import pandas as pd

# 1. Cargar el CSV
df = pd.read_csv("consoles2.csv")

# 2. Ver las cabeceras originales
print(df.columns)
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
df.columns.values
# Out:
# array(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher',
#        'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales',
#        'Critic_Score', 'Critic_Count', 'User_Score', 'User_Count',
#        'Developer', 'Rating'], dtype=object)

# %%
ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: EE48-8C8C
#
#  Directorio de C:\Users\Edu_t\Desktop\Educem\ASIX2\0378-Seguretat_i_alta_disponibiltat\notebook\Notebook-consolas
#
# 01/10/2025  17:42    <DIR>          .
# 01/10/2025  17:42    <DIR>          ..
# 29/09/2025  16:08    <DIR>          .ipynb_checkpoints
# 20/09/2019  04:04         1.618.040 consoles.csv
# 01/10/2025  17:35           793.532 consoles2.csv
# 01/10/2025  17:36           793.591 consoles2_es.csv
# 29/09/2025  15:36                32 README.md
# 01/10/2025  17:42            46.201 Untitled.ipynb
#                5 archivos      3.251.396 bytes
#                3 dirs  283.274.526.720 bytes libres

# %%
print(df)
# Out:
#                                    Name Platform  Year_of_Release     Genre  \
# 0                            Wii Sports      Wii           2006.0    Sports
# 1                        Mario Kart Wii      Wii           2008.0    Racing
# 2                     Wii Sports Resort      Wii           2009.0    Sports
# 3                 New Super Mario Bros.       DS           2006.0  Platform
# 4                              Wii Play      Wii           2006.0      Misc
# ...                                 ...      ...              ...       ...
# 6820         E.T. The Extra-Terrestrial      GBA           2001.0    Action
# 6821     Mortal Kombat: Deadly Alliance      GBA           2002.0  Fighting
# 6822  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 6823                             Breach       PC           2011.0   Shooter
# 6824            STORM: Frontline Nation       PC           2011.0  Strategy
#
#                          Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                         Nintendo     41.36     28.96      3.77         8.45
# 1                         Nintendo     15.68     12.76      3.79         3.29
# 2                         Nintendo     15.61     10.93      3.28         2.95
# 3                         Nintendo     11.28      9.14      6.50         2.88
# 4                         Nintendo     13.96      9.18      2.93         2.84
# ...                            ...       ...       ...       ...          ...
# 6820                      NewKidCo      0.01      0.00      0.00         0.00
# 6821                  Midway Games      0.01      0.00      0.00         0.00
# 6822  Konami Digital Entertainment      0.00      0.01      0.00         0.00
# 6823                     Destineer      0.01      0.00      0.00         0.00
# 6824                       Unknown      0.00      0.01      0.00         0.00
#
#       Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count  \
# 0            82.53          76.0          51.0         8.0       322.0
# 1            35.52          82.0          73.0         8.3       709.0
# 2            32.77          80.0          73.0         8.0       192.0
# 3            29.80          89.0          65.0         8.5       431.0
# 4            28.92          58.0          41.0         6.6       129.0
# ...            ...           ...           ...         ...         ...
# 6820          0.01          46.0           4.0         2.4        21.0
# 6821          0.01          81.0          12.0         8.8         9.0
# 6822          0.01          80.0          20.0         7.6       412.0
# 6823          0.01          61.0          12.0         5.8        43.0
# 6824          0.01          60.0          12.0         7.2        13.0
#
#                Developer Rating
# 0               Nintendo      E
# 1               Nintendo      E
# 2               Nintendo      E
# 3               Nintendo      E
# 4               Nintendo      E
# ...                  ...    ...
# 6820       Fluid Studios      E
# 6821     Criterion Games      M
# 6822  Kojima Productions      M
# 6823        Atomic Games      T
# 6824              SimBin   E10+
#
# [6825 rows x 16 columns]

# %%
import pandas as pd

# 1. Cargar el CSV
df = pd.read_csv("consoles2.csv")

# 2. Ver las cabeceras originales
print(df.columns)

# 3. Renombrar las columnas al español
df = df.rename(columns={
    "Platform": "Plataforma",
    "Year_of_Release": "Año_de_Lanzamiento",
    "Genre": "Género",
    "Publisher": "Editor",
    "NA_Sales": "Ventas_NA",
    "EU_Sales": "Ventas_EU",
    "JP_Sales": "Ventas_JP",
    "Other_Sales": "Otras_Ventas",
    "Global_Sales": "Ventas_Globales",
    "Critic_Score": "Puntuación_Crítica",
    "Critic_Count": "Número_Críticas",
    "User_Score": "Puntuación_Usuarios",
    "User_Count": "Número_Usuarios",
    "Developer": "Desarrolladora",
    "Rating": "Clasificación_ESRB"
})

# 4. Confirmar los cambios
print(df.columns)

# 5. (Opcional) Guardar el CSV con las nuevas cabeceras
df.to_csv("consoles2_es.csv", index=True)
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')
# Index(['Name', 'Plataforma', 'Año_de_Lanzamiento', 'Género', 'Editor',
#        'Ventas_NA', 'Ventas_EU', 'Ventas_JP', 'Otras_Ventas',
#        'Ventas_Globales', 'Puntuación_Crítica', 'Número_Críticas',
#        'Puntuación_Usuarios', 'Número_Usuarios', 'Desarrolladora',
#        'Clasificación_ESRB'],
#       dtype='object')

# %%
df = pd.read_csv("consoles2_es.csv")

# %%
df = df.rename(columns={
    "Name": "Título"})

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Título', 'Plataforma', 'Año_de_Lanzamiento', 'Género',
#        'Editor', 'Ventas_NA', 'Ventas_EU', 'Ventas_JP', 'Otras_Ventas',
#        'Ventas_Globales', 'Puntuación_Crítica', 'Número_Críticas',
#        'Puntuación_Usuarios', 'Número_Usuarios', 'Desarrolladora',
#        'Clasificación_ESRB'],
#       dtype='object')

# %%
df.to_csv("consoles2_es.csv", index=True)

# %%
df = df.drop(df.columns[0], axis=1)

# %%
print(df.columns"
# Out:
#   Cell In[32], line 1
#     print(df.columns"
#                     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print(df.columns)
# Out:
# Index(['Título', 'Plataforma', 'Año_de_Lanzamiento', 'Género', 'Editor',
#        'Ventas_NA', 'Ventas_EU', 'Ventas_JP', 'Otras_Ventas',
#        'Ventas_Globales', 'Puntuación_Crítica', 'Número_Críticas',
#        'Puntuación_Usuarios', 'Número_Usuarios', 'Desarrolladora',
#        'Clasificación_ESRB'],
#       dtype='object')

# %%
df.to_csv("consoles2_es.csv", index=True)

# %%
print(df.columns)
# Out:
# Index(['Título', 'Plataforma', 'Año_de_Lanzamiento', 'Género', 'Editor',
#        'Ventas_NA', 'Ventas_EU', 'Ventas_JP', 'Otras_Ventas',
#        'Ventas_Globales', 'Puntuación_Crítica', 'Número_Críticas',
#        'Puntuación_Usuarios', 'Número_Usuarios', 'Desarrolladora',
#        'Clasificación_ESRB'],
#       dtype='object')

# %%
df.to_csv("consoles2_es.csv", index=False)

# %%
df["año_de_lanzamiento"] = df["año_de_lanzamiento"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df["año_de_lanzamiento"] = df["año_de_lanzamiento"].astype(int)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# 1. Cargar el CSV
df = pd.read_csv("consoles2_es.csv")
df["año_de_lanzamiento"] = df["año_de_lanzamiento"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'año_de_lanzamiento'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 5
#       3 # 1. Cargar el CSV
#       4 df = pd.read_csv("consoles2_es.csv")
# ----> 5 df["año_de_lanzamiento"] = df["año_de_lanzamiento"].astype(int)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'año_de_lanzamiento'

# %%
import pandas as pd

# 1. Cargar el CSV
df = pd.read_csv("consoles2_es.csv")
df["Año_de_Lanzamiento"] = df["Año_de_Lanzamiento"].astype(int)

# %%
import pandas as pd

# 1. Cargar el CSV
df = pd.read_csv("consoles2_es.csv")
df["Año_de_Lanzamiento"] = df["Año_de_Lanzamiento"].astype(int)

# %%
# 4. Confirmar los cambios
print(df.columns)

# 5. (Opcional) Guardar el CSV con las nuevas cabeceras
df.to_csv("consoles2_es.csv", index=True)
# Out:
# Index(['Título', 'Plataforma', 'Año_de_Lanzamiento', 'Género', 'Editor',
#        'Ventas_NA', 'Ventas_EU', 'Ventas_JP', 'Otras_Ventas',
#        'Ventas_Globales', 'Puntuación_Crítica', 'Número_Críticas',
#        'Puntuación_Usuarios', 'Número_Usuarios', 'Desarrolladora',
#        'Clasificación_ESRB'],
#       dtype='object')

# %%
import pandas as pd

# 1. Cargar el CSV
df = pd.read_csv("consoles2_es.csv")
df["Número_Usuarios"] = df["Número_Usuarios"].astype(int)
# 4. Confirmar los cambios
print(df.columns)

# 5. (Opcional) Guardar el CSV con las nuevas cabeceras
df.to_csv("consoles2_es.csv", index=True)
# Out:
# Index(['Unnamed: 0', 'Título', 'Plataforma', 'Año_de_Lanzamiento', 'Género',
#        'Editor', 'Ventas_NA', 'Ventas_EU', 'Ventas_JP', 'Otras_Ventas',
#        'Ventas_Globales', 'Puntuación_Crítica', 'Número_Críticas',
#        'Puntuación_Usuarios', 'Número_Usuarios', 'Desarrolladora',
#        'Clasificación_ESRB'],
#       dtype='object')

# %%
df = df.drop("nombre_columna", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = df.drop("nombre_columna", axis=1)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
#    5595         errors=errors,
#    5596     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:4807, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4805 for axis, labels in axes.items():
#    4806     if labels is not None:
# -> 4807         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4809 if inplace:
#    4810     self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:4849, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4847         new_axis = axis.drop(labels, level=level, errors=errors)
#    4848     else:
# -> 4849         new_axis = axis.drop(labels, errors=errors)
#    4850     indexer = axis.get_indexer(new_axis)
#    4852 # Case for non-unique axis
#    4853 else:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['nombre_columna'] not found in axis"

# %%
df = df.drop(df.columns[:2], axis=1)

# %%
df.to_csv("consoles2_es.csv", index=False)

# %%
import pandas as pd
df = pd.read_csv("Video_Games_español.csv")

# Diccionario para traducir las clasificaciones ESRB al español
clasificacion_map = {
    "E": "E (Para todos a partir de 6 años)",
    "M": "M (Adultos a partir de 17 años)",
    "T": "T (Adolescentes a partir de 13 años)",
    "E10+": "E10+ (Para todos a partir de 10 años)",
    "AO": "AO (Solo adultos, mayores de 18 años)",
    "EC": "EC (Primera infancia, desde 3 años)",
    "RP": "RP (Clasificación pendiente)"
}

# Aplicar la traducción a la columna 'Clasificación'
df['Clasificación_ESRB'] = df['Clasificación_ESRB'].map(clasificacion_map)

# Mostrar las primeras filas para verificar
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("Video_Games_español.csv")
#       4 # Diccionario para traducir las clasificaciones ESRB al español
#       5 clasificacion_map = {
#       6     "E": "E (Para todos a partir de 6 años)",
#       7     "M": "M (Adultos a partir de 17 años)",
#    (...)     12     "RP": "RP (Clasificación pendiente)"
#      13 }
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Video_Games_español.csv'

# %%
import pandas as pd
df = pd.read_csv("consoles2_es.csv")

# Diccionario para traducir las clasificaciones ESRB al español
clasificacion_map = {
    "E": "E (Para todos a partir de 6 años)",
    "M": "M (Adultos a partir de 17 años)",
    "T": "T (Adolescentes a partir de 13 años)",
    "E10+": "E10+ (Para todos a partir de 10 años)",
    "AO": "AO (Solo adultos, mayores de 18 años)",
    "EC": "EC (Primera infancia, desde 3 años)",
    "RP": "RP (Clasificación pendiente)"
}

# Aplicar la traducción a la columna 'Clasificación'
df['Clasificación'] = df['Clasificación'].map(clasificacion_map)

# Mostrar las primeras filas para verificar
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Clasificación'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 16
#       5 clasificacion_map = {
#       6     "E": "E (Para todos a partir de 6 años)",
#       7     "M": "M (Adultos a partir de 17 años)",
#    (...)     12     "RP": "RP (Clasificación pendiente)"
#      13 }
#      15 # Aplicar la traducción a la columna 'Clasificación'
# ---> 16 df['Clasificación'] = df['Clasificación'].map(clasificacion_map)
#      18 # Mostrar las primeras filas para verificar
#      19 df.head()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Clasificación'

# %%
import pandas as pd

df = pd.read_csv("consoles2_es.csv")

# Diccionario para traducir las clasificaciones ESRB al español
clasificacion_map = {
    "E": "E (Para todos a partir de 6 años)",
    "M": "M (Adultos a partir de 17 años)",
    "T": "T (Adolescentes a partir de 13 años)",
    "E10+": "E10+ (Para todos a partir de 10 años)",
    "AO": "AO (Solo adultos, mayores de 18 años)",
    "EC": "EC (Primera infancia, desde 3 años)",
    "RP": "RP (Clasificación pendiente)"
}

# Aplicar la traducción a la columna 'Clasificación'
df['Clasificación'] = df['Clasificación'].map(clasificacion_map)

# Mostrar las primeras filas para verificar
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Clasificación'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 17
#       6 clasificacion_map = {
#       7     "E": "E (Para todos a partir de 6 años)",
#       8     "M": "M (Adultos a partir de 17 años)",
#    (...)     13     "RP": "RP (Clasificación pendiente)"
#      14 }
#      16 # Aplicar la traducción a la columna 'Clasificación'
# ---> 17 df['Clasificación'] = df['Clasificación'].map(clasificacion_map)
#      19 # Mostrar las primeras filas para verificar
#      20 df.head()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Clasificación'

# %%
import pandas as pd
df = pd.read_csv("Video_Games_español.csv")

# Diccionario para traducir las clasificaciones ESRB al español
clasificacion_map = {
    "E": "E (Para todos a partir de 6 años)",
    "M": "M (Adultos a partir de 17 años)",
    "T": "T (Adolescentes a partir de 13 años)",
    "E10+": "E10+ (Para todos a partir de 10 años)",
    "AO": "AO (Solo adultos, mayores de 18 años)",
    "EC": "EC (Primera infancia, desde 3 años)",
    "RP": "RP (Clasificación pendiente)"
}

# Aplicar la traducción a la columna 'Clasificación'
df['Clasificación_ESRB'] = df['Clasificación_ESRB'].map(clasificacion_map)

# Mostrar las primeras filas para verificar
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("Video_Games_español.csv")
#       4 # Diccionario para traducir las clasificaciones ESRB al español
#       5 clasificacion_map = {
#       6     "E": "E (Para todos a partir de 6 años)",
#       7     "M": "M (Adultos a partir de 17 años)",
#    (...)     12     "RP": "RP (Clasificación pendiente)"
#      13 }
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Video_Games_español.csv'

# %%
import pandas as pd
df = pd.read_csv("consoles2_es.csv")

# Diccionario para traducir las clasificaciones ESRB al español
clasificacion_map = {
    "E": "E (Para todos a partir de 6 años)",
    "M": "M (Adultos a partir de 17 años)",
    "T": "T (Adolescentes a partir de 13 años)",
    "E10+": "E10+ (Para todos a partir de 10 años)",
    "AO": "AO (Solo adultos, mayores de 18 años)",
    "EC": "EC (Primera infancia, desde 3 años)",
    "RP": "RP (Clasificación pendiente)"
}

# Aplicar la traducción a la columna 'Clasificación'
df['Clasificación_ESRB'] = df['Clasificación_ESRB'].map(clasificacion_map)

# Mostrar las primeras filas para verificar
df.head()
# Out:
#   Plataforma  Año_de_Lanzamiento    Género    Editor  Ventas_NA  Ventas_EU  \
# 0        Wii                2006    Sports  Nintendo      41.36      28.96
# 1        Wii                2008    Racing  Nintendo      15.68      12.76
# 2        Wii                2009    Sports  Nintendo      15.61      10.93
# 3         DS                2006  Platform  Nintendo      11.28       9.14
# 4        Wii                2006      Misc  Nintendo      13.96       9.18
#
#    Ventas_JP  Otras_Ventas  Ventas_Globales  Puntuación_Crítica  \
# 0       3.77          8.45            82.53                76.0
# 1       3.79          3.29            35.52                82.0
# 2       3.28          2.95            32.77                80.0
# 3       6.50          2.88            29.80                89.0
# 4       2.93          2.84            28.92                58.0
#
#    Número_Críticas  Puntuación_Usuarios  Número_Usuarios Desarrolladora  \
# 0             51.0                  8.0              322       Nintendo
# 1             73.0                  8.3              709       Nintendo
# 2             73.0                  8.0              192       Nintendo
# 3             65.0                  8.5              431       Nintendo
# 4             41.0                  6.6              129       Nintendo
#
#                   Clasificación_ESRB
# 0  E (Para todos a partir de 6 años)
# 1  E (Para todos a partir de 6 años)
# 2  E (Para todos a partir de 6 años)
# 3  E (Para todos a partir de 6 años)
# 4  E (Para todos a partir de 6 años)

# %%
import pandas as pd
df = pd.read_csv("consoles2_es.csv")

# Diccionario para traducir las clasificaciones ESRB al español
clasificacion_map = {
    "E": "E (6 años)",
    "M": "M (17 años)",
    "T": "T (13 años)",
    "E10+": "E10+ (10 años)",
    "AO": "AO (18 años)",
    "EC": "EC (3 años)",
    "RP": "RP (Clasificación pendiente)"
}

# Aplicar la traducción a la columna 'Clasificación'
df['Clasificación_ESRB'] = df['Clasificación_ESRB'].map(clasificacion_map)

# Mostrar las primeras filas para verificar
df.head()
# Out:
#   Plataforma  Año_de_Lanzamiento    Género    Editor  Ventas_NA  Ventas_EU  \
# 0        Wii                2006    Sports  Nintendo      41.36      28.96
# 1        Wii                2008    Racing  Nintendo      15.68      12.76
# 2        Wii                2009    Sports  Nintendo      15.61      10.93
# 3         DS                2006  Platform  Nintendo      11.28       9.14
# 4        Wii                2006      Misc  Nintendo      13.96       9.18
#
#    Ventas_JP  Otras_Ventas  Ventas_Globales  Puntuación_Crítica  \
# 0       3.77          8.45            82.53                76.0
# 1       3.79          3.29            35.52                82.0
# 2       3.28          2.95            32.77                80.0
# 3       6.50          2.88            29.80                89.0
# 4       2.93          2.84            28.92                58.0
#
#    Número_Críticas  Puntuación_Usuarios  Número_Usuarios Desarrolladora  \
# 0             51.0                  8.0              322       Nintendo
# 1             73.0                  8.3              709       Nintendo
# 2             73.0                  8.0              192       Nintendo
# 3             65.0                  8.5              431       Nintendo
# 4             41.0                  6.6              129       Nintendo
#
#   Clasificación_ESRB
# 0         E (6 años)
# 1         E (6 años)
# 2         E (6 años)
# 3         E (6 años)
# 4         E (6 años)

# %%
df.to_csv("consoles2_es.csv", index=False)
